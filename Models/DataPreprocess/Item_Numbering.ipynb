# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np

# %%
reviewDF = pd.read_csv("/content/gdrive/MyDrive/Data/philadelphia_rating.csv")
reviewDF.head()
# Out:
#                   user_id             business_id  stars  newUserId  \
# 0  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA      5          1
# 1  kSMOJwJXuEUqzfmuFncK4A  kxX2SOes4o-D3ZQBkiMRfA      2          2
# 2  mqBWACmaHflW4eh_Ofp16Q  kxX2SOes4o-D3ZQBkiMRfA      5          3
# 3  mqBWACmaHflW4eh_Ofp16Q  kxX2SOes4o-D3ZQBkiMRfA      5          3
# 4  Z-xgVb4nM42943m2wbBkFw  kxX2SOes4o-D3ZQBkiMRfA      5          4
#
#    newBusinessId
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# ---

# %% [markdown]
# ## 비즈니스 넘버링

# %%
businessID = reviewDF[['business_id', 'newBusinessId']].drop_duplicates()

print('shape: ', businessID.shape)
print('min', businessID['newBusinessId'].min())
print('max', businessID['newBusinessId'].max())

businessID.head()
# Out:
# shape:  (7076, 2)
# min 1
# max 7076
#                 business_id  newBusinessId
# 0    kxX2SOes4o-D3ZQBkiMRfA              1
# 190  O6hY9yenifuRXrpc4TfgsQ            120
# 711  YpV0DniZQKnG6mWVVl-TSw           3105
# 769  5ebgEvBg1-harVzszDA02g           3643
# 798  6KXJk2AWH3NxZBuCdkggVQ           5101

# %%
businessDF = pd.read_csv("/content/gdrive/MyDrive/Data/philadelphia_business.csv")
businessDF.head()
# Out:
#               business_id   latitude  longitude  \
# 0  MTSW4McQd7CbVtyjqoe9mw  39.955505 -75.155564
# 1  MUTTqe8uqyMdBl186RmNeA  39.953949 -75.143226
# 2  ROeacJQwBeh05Rqg7F6TCg  39.943223 -75.162568
# 3  QdN72BWoyFypdGJhhI5r7g  39.939825 -75.157447
# 4  Mjboz24M9NlBeiOJKLEd_Q  40.022466 -75.218314
#
#                                           categories
# 0  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 1                  Sushi Bars, Restaurants, Japanese
# 2                                Korean, Restaurants
# 3  Cocktail Bars, Bars, Italian, Nightlife, Resta...
# 4                    Pizza, Restaurants, Salad, Soup

# %%
result = pd.merge(businessDF, businessID, on='business_id')
result.head()
# Out:
#               business_id   latitude  longitude  \
# 0  MTSW4McQd7CbVtyjqoe9mw  39.955505 -75.155564
# 1  MUTTqe8uqyMdBl186RmNeA  39.953949 -75.143226
# 2  ROeacJQwBeh05Rqg7F6TCg  39.943223 -75.162568
# 3  QdN72BWoyFypdGJhhI5r7g  39.939825 -75.157447
# 4  Mjboz24M9NlBeiOJKLEd_Q  40.022466 -75.218314
#
#                                           categories  newBusinessId
# 0  Restaurants, Food, Bubble Tea, Coffee & Tea, B...            236
# 1                  Sushi Bars, Restaurants, Japanese            158
# 2                                Korean, Restaurants            206
# 3  Cocktail Bars, Bars, Italian, Nightlife, Resta...            131
# 4                    Pizza, Restaurants, Salad, Soup            308

# %%
result.to_csv("/content/gdrive/MyDrive/Data/philadelphia_business_numbering.csv", index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## 사용자 넘버링

# %%
userID = reviewDF[['user_id', 'newUserId']].drop_duplicates()

print('shape: ', userID.shape)
print('min', userID['newUserId'].min())
print('max', userID['newUserId'].max())

userID.head()
# Out:
# shape:  (216944, 2)
# min 1
# max 216944
#                   user_id  newUserId
# 0  _7bHUi9Uuf5__HHc_Q8guQ          1
# 1  kSMOJwJXuEUqzfmuFncK4A          2
# 2  mqBWACmaHflW4eh_Ofp16Q          3
# 4  Z-xgVb4nM42943m2wbBkFw          4
# 5  2SEoXb6r6hPKrl9V9VzBgA          5

# %%
userDF = pd.read_csv("/content/gdrive/MyDrive/Data/philadelphia_user.csv")
userDF.head()
# Out:
#                   user_id    name
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel
# 2  q_QQ5kBBwlCcbL1s4NVK3g    Jane
# 3  AUi8MPWJ0mLkMfwbui27lg    John
# 4  1McG5Rn_UDkmlkZOrsdptg  Teresa

# %%
result = pd.merge(userDF, userID, on='user_id')
result.head()
# Out:
#                   user_id    name  newUserId
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker     135854
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel      56469
# 2  q_QQ5kBBwlCcbL1s4NVK3g    Jane      24825
# 3  AUi8MPWJ0mLkMfwbui27lg    John       2210
# 4  1McG5Rn_UDkmlkZOrsdptg  Teresa      17454

# %%
result.to_csv("/content/gdrive/MyDrive/Data/philadelphia_user_numbering.csv", index=False)
