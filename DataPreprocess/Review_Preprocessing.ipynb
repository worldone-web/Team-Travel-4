# %% [markdown]
# # Review DataSet 확인

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("yelp_dataset\csv\yelp_academic_dataset_review.csv")
df.head()
# Out:
#               business_id  cool                 date  funny  \
# 0  XQfwVwDr-v0ZS3_CbbE5Xw     0  2018-07-07 22:09:11      0
# 1  7ATYjTIgM3jUlt4UM3IypQ     1  2012-01-03 15:28:18      0
# 2  YjUWPpI6HXG530lwP-fb2A     0  2014-02-05 20:30:30      0
# 3  kxX2SOes4o-D3ZQBkiMRfA     1  2015-01-04 00:01:03      0
# 4  e4Vwtrqf-wpJfwesgvdgxQ     1  2017-01-14 20:54:15      0
#
#                 review_id  stars  \
# 0  KU_O5udG6zpxOg-VcAEodg      3
# 1  BiTunyQ73aT9WBnpR9DZGw      5
# 2  saUsX_uimxRlCVr67Z4Jig      3
# 3  AqPFMleE6RsU23_auESxiA      5
# 4  Sx8TMOWLNuJBWer-0pcmoA      4
#
#                                                 text  useful  \
# 0  If you decide to eat here, just be aware it is...       0
# 1  I've taken a lot of spin classes over the year...       1
# 2  Family diner. Had the buffet. Eclectic assortm...       0
# 3  Wow!  Yummy, different,  delicious.   Our favo...       1
# 4  Cute interior and owner (?) gave us tour of up...       1
#
# ...

# %%
df.shape
# Out:
# (6990280, 9)

# %%
df_a = df[["user_id", "business_id", "stars"]]
df_a.head()
# Out:
#                   user_id             business_id  stars
# 0  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw      3
# 1  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ      5
# 2  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A      3
# 3  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA      5
# 4  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ      4

# %% [markdown]
# # Philadelphia의 Business 가져오기

# %%
df_b = pd.read_csv("yelp_dataset\csv\yelp_academic_dataset_business.csv")
df_b = df_b[["business_id", "city", "state", "categories"]]
df_b = df_b[df_b.city=="Philadelphia"]
df_b = df_b.dropna(subset="categories")
df_b = df_b[df_b["categories"].str.contains("Restaurants|Food")]
df_b
# Out:
#                    business_id          city state  \
# 3       MTSW4McQd7CbVtyjqoe9mw  Philadelphia    PA
# 15      MUTTqe8uqyMdBl186RmNeA  Philadelphia    PA
# 19      ROeacJQwBeh05Rqg7F6TCg  Philadelphia    PA
# 28      QdN72BWoyFypdGJhhI5r7g  Philadelphia    PA
# 31      Mjboz24M9NlBeiOJKLEd_Q  Philadelphia    PA
# ...                        ...           ...   ...
# 150287  VZbkSeZtFynEascotq7ExA  Philadelphia    PA
# 150298  gPr1io7ks0Eo3FDsnDTYfg  Philadelphia    PA
# 150306  wVxXRFf10zTTAs11nr4xeA  Philadelphia    PA
# 150319  8n93L-ilMAsvwUatarykSg  Philadelphia    PA
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Philadelphia    PA
#
#                                                categories
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 15                      Sushi Bars, Restaurants, Japanese
# 19                                    Korean, Restaurants
# 28      Cocktail Bars, Bars, Italian, Nightlife, Resta...
# ...

# %% [markdown]
# # Philadelphia의 Review 추출

# %%
df_join = pd.merge(df_a, df_b, left_on="business_id", right_on="business_id", how="inner")
df_join
# Out:
#                        user_id             business_id  stars          city  \
# 0       _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA      5  Philadelphia
# 1       kSMOJwJXuEUqzfmuFncK4A  kxX2SOes4o-D3ZQBkiMRfA      2  Philadelphia
# 2       mqBWACmaHflW4eh_Ofp16Q  kxX2SOes4o-D3ZQBkiMRfA      5  Philadelphia
# 3       Z-xgVb4nM42943m2wbBkFw  kxX2SOes4o-D3ZQBkiMRfA      5  Philadelphia
# 4       2SEoXb6r6hPKrl9V9VzBgA  kxX2SOes4o-D3ZQBkiMRfA      5  Philadelphia
# ...                        ...                     ...    ...           ...
# 738683  reFwg-F-MCoRS1pA2YexMg  BEuGzy5gxtGyOEk8iwDfTg      5  Philadelphia
# 738684  dh3UhfqpFSoCitl8WCrdfw  BEuGzy5gxtGyOEk8iwDfTg      5  Philadelphia
# 738685  nXwPLYvazD_Nd2Sar3eSWA  BEuGzy5gxtGyOEk8iwDfTg      5  Philadelphia
# 738686  MlOJCxiiB1TeZN-is2Q4SA  BEuGzy5gxtGyOEk8iwDfTg      5  Philadelphia
# 738687  AKXL58tPS_jNdT5DH5NhhA  BEuGzy5gxtGyOEk8iwDfTg      5  Philadelphia
#
# ...

# %% [markdown]
# # 최종 전처리

# %% [markdown]
# ## Business_info { id, location, category } 생성

# %%
df_join = df_join[["user_id", "business_id", "stars"]]
df_join.head()
# Out:
#                   user_id             business_id  stars
# 0  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA      5
# 1  kSMOJwJXuEUqzfmuFncK4A  kxX2SOes4o-D3ZQBkiMRfA      2
# 2  mqBWACmaHflW4eh_Ofp16Q  kxX2SOes4o-D3ZQBkiMRfA      5
# 3  Z-xgVb4nM42943m2wbBkFw  kxX2SOes4o-D3ZQBkiMRfA      5
# 4  2SEoXb6r6hPKrl9V9VzBgA  kxX2SOes4o-D3ZQBkiMRfA      5

# %% [markdown]
# ### 저장 및 확인

# %%
# df_join.to_csv("philadelphia_reviews.csv", encoding="utf-8", index=False)

# %%
df_review = pd.read_csv("philadelphia_reviews.csv")
df_review
# Out:
#                        user_id             business_id  stars
# 0       _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA      5
# 1       kSMOJwJXuEUqzfmuFncK4A  kxX2SOes4o-D3ZQBkiMRfA      2
# 2       mqBWACmaHflW4eh_Ofp16Q  kxX2SOes4o-D3ZQBkiMRfA      5
# 3       Z-xgVb4nM42943m2wbBkFw  kxX2SOes4o-D3ZQBkiMRfA      5
# 4       2SEoXb6r6hPKrl9V9VzBgA  kxX2SOes4o-D3ZQBkiMRfA      5
# ...                        ...                     ...    ...
# 738683  reFwg-F-MCoRS1pA2YexMg  BEuGzy5gxtGyOEk8iwDfTg      5
# 738684  dh3UhfqpFSoCitl8WCrdfw  BEuGzy5gxtGyOEk8iwDfTg      5
# 738685  nXwPLYvazD_Nd2Sar3eSWA  BEuGzy5gxtGyOEk8iwDfTg      5
# 738686  MlOJCxiiB1TeZN-is2Q4SA  BEuGzy5gxtGyOEk8iwDfTg      5
# 738687  AKXL58tPS_jNdT5DH5NhhA  BEuGzy5gxtGyOEk8iwDfTg      5
#
# [738688 rows x 3 columns]

# %% [markdown]
# # User, Business ID 정수형변환

# %%
uids = df_review["user_id"].unique()
uids.sort()
uids
len(uids)
# Out:
# 216944

# %%
idx = 1
for uid in uids:
    df_review.loc[df_review.user_id == uid, "user_id"] = idx
    print(df_review[df_review.user_id == idx])
    idx += 1
# Out:
#        user_id             business_id  stars
# 254559       1  5UN1B7XqZohGuULLNlWL1A      5
#        user_id             business_id  stars
# 105889       2  qcguEeAMP0XwFLYqhwX2hg      5
# 423891       2  Y5S_AUSW8EjswVf9JAi-0w      4
#        user_id             business_id  stars
# 382796       3  U2y7fsqDgxAXskoJNVxbwg      2
#        user_id             business_id  stars
# 17974        4  L3V21nAe-CicW2bvtNWa0g      2
# 356832       4  IXRSMV7U5D0sYJvArEbm5g      3
# 391496       4  jHZS9GIhW7s9r4w5w-0A0Q      3
# 540364       4  eoN0GAIRV0WmwUm7FmzKgQ      4
# 665173       4  vXb4OWsjPoiBtmarfexj-g      4
#        user_id             business_id  stars
# 287896       5  krCwF4raTYvBcCEwcbA88Q      4
# 423513       5  IBIp-yVFl2PxYS-rgc19Yg      5
#        user_id             business_id  stars
# 1895         6  EtKSTHV5Qx_Q7Aur9o4kQQ      4
# 28308        6  wUnLSg_GKfEIQ5CQQ770_g      4
# 235110       6  a62d7e_xXeljJcOUHkJjkg      5
# ...

# %%
idx = 1
for bid in bids:
    df_review.loc[df_review.user_id == uid, "user_id"] = idx
    print(df_review[df_review.user_id == idx])
    idx += 1
